# %%
# !pip install easyocr
# !pip install imutils
# Out:
# Requirement already satisfied: easyocr in c:\users\kisha\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: scipy in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (1.9.1)
# Requirement already satisfied: opencv-python-headless in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (4.8.1.78)
# Requirement already satisfied: ninja in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: numpy in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (1.24.4)
# Requirement already satisfied: torchvision>=0.5 in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (0.14.1)
# Requirement already satisfied: python-bidi in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: Pillow in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (9.2.0)
# Requirement already satisfied: Shapely in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: scikit-image in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (0.19.2)
# Requirement already satisfied: pyclipper in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: PyYAML in c:\users\kisha\anaconda3\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: requests in c:\users\kisha\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\users\kisha\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: six in c:\users\kisha\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kisha\anaconda3\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\kisha\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kisha\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\kisha\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.8.4)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\kisha\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kisha\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kisha\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kisha\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kisha\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kisha\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: imutils in c:\users\kisha\anaconda3\lib\site-packages (0.5.4)

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
img = cv2.imread('image1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9988\3830115655.py in <module>
#       1 img = cv2.imread('image1.jpg')
# ----> 2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       3 plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/kisha/Downloads/image2 (2).jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.show()

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17)
edged = cv2.Canny(bfilter, 30, 200)
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[122, 219]],
#
#        [[246, 227]],
#
#        [[252, 200]],
#
#        [[132, 191]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0, 255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[6, 4], [128, 4], [128, 34], [6, 34]], 'HR.26 BR.9044', 0.5728024956877317)]
